# %%
import requests
# beautify the data we fetch to read
from bs4 import BeautifulSoup as bs
# urlib provide functionality to open url automatically
from urllib.request import urlopen
# import logging

# %%
url="https://www.flipkart.com/search?q="+"iphone"

# %%
url
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
urlclient=urlopen(url)

# %%
# open url, thus we get HTTp response from it
urlclient
a=urlclient.read()

# %%
readable=bs(a,"html.parser")

# %%
readable
# Out:
# <!DOCTYPE html>
# ...

# %%
needed_section=readable.findAll("div",{"class":"_1YokD2 _3Mn1Gg"})

# %%
needed_section
# Out:
# [<div class="_1YokD2 _3Mn1Gg" style="flex-grow:1;overflow:auto"><div class="_1YokD2 _2GoDe3 col-12-12" style="background-color:#ffffff;align-items:flex-end"><div class="_1AtVbE" style="flex-grow:1;overflow:auto"><div class="W_R1IA"><div class="_1MR4o5"><div class="_3GIHBu"><a class="_2whKao" href="/">Home</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles-accessories/pr?sid=tyy&amp;marketplace=FLIPKART">Mobiles &amp; Accessories</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles/pr?sid=tyy,4io&amp;marketplace=FLIPKART">Mobiles</a><svg cla
# ...

# %%
needed_section
# Out:
# [<div class="_1YokD2 _3Mn1Gg" style="flex-grow:1;overflow:auto"><div class="_1YokD2 _2GoDe3 col-12-12" style="background-color:#ffffff;align-items:flex-end"><div class="_1AtVbE" style="flex-grow:1;overflow:auto"><div class="W_R1IA"><div class="_1MR4o5"><div class="_3GIHBu"><a class="_2whKao" href="/">Home</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles-accessories/pr?sid=tyy&amp;marketplace=FLIPKART">Mobiles &amp; Accessories</a><svg class="_39X-Og" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg"><path class="DpXnhQ" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></div><div class="_3GIHBu"><a class="_2whKao" href="/mobiles/pr?sid=tyy,4io&amp;marketplace=FLIPKART">Mobiles</a><svg cla
# ...

# %%
len(needed_section)
# Out:
# 1

# %%
box=readable.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(box)
# Out:
# 30

# %%
box[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4i
# ...

# %%
item=box[0].div.div.div.a

# %%
item

# %%
box[0].div
# Out:
# <div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=iphone&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?sid=tyy,4io&amp;q=iphone&amp;otracker=cat
# ...

# %%
box[0].div.div
# Out:
# <div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div>

# %%
box[0].div.div.div
# Out:
# <div class="_3V8rao"><span>Filters</span></div>

# %%
item=box[2].div.div.div.a

# %%
item
# Out:
# <a class="_1fQZEK" href="/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&amp;lid=LSTMOBGTAGPAQNVFZZYSCIIOB&amp;marketplace=FLIPKART&amp;q=iphone&amp;store=tyy%2F4io&amp;spotlightTagId=BestsellerId_tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=412065c4-621b-4627-84e7-b973d5ebb15b.MOBGTAGPAQNVFZZY.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=4nhnootua80000001708112343637&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank"><div></div><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="Apple iPhone 15 (Blue, 128 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/k/l/l/-original-imagtc5fz9spysyk.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>
# ...

# %%
item['href']
# Out:
# '/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYSCIIOB&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=412065c4-621b-4627-84e7-b973d5ebb15b.MOBGTAGPAQNVFZZY.SEARCH&ppt=None&ppn=None&ssid=4nhnootua80000001708112343637&qH=0b3f45b266a97d70'

# %%
del box[0:2]

# %%
del box[24:]

# %%
count=0
for i in box:
    count+=1
    print(count)
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# 1
# https://www.flipkart.com/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYSCIIOB&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=412065c4-621b-4627-84e7-b973d5ebb15b.MOBGTAGPAQNVFZZY.SEARCH&ppt=None&ppn=None&ssid=4nhnootua80000001708112343637&qH=0b3f45b266a97d70
# 2
# https://www.flipkart.com/apple-iphone-15-black-128-gb/p/itm6ac6485515ae4?pid=MOBGTAGPTB3VS24W&lid=LSTMOBGTAGPTB3VS24W7RH6ZZ&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=412065c4-621b-4627-84e7-b973d5ebb15b.MOBGTAGPTB3VS24W.SEARCH&ppt=None&ppn=None&ssid=4nhnootua80000001708112343637&qH=0b3f45b266a97d70
# 3
# ...

# %%
product_req="https://www.flipkart.com"+box[0].div.div.div.a['href']

# %%
product_req
# Out:
# 'https://www.flipkart.com/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYSCIIOB&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=412065c4-621b-4627-84e7-b973d5ebb15b.MOBGTAGPAQNVFZZY.SEARCH&ppt=None&ppn=None&ssid=4nhnootua80000001708112343637&qH=0b3f45b266a97d70'

# %%
# fetch data from the url
product=requests.get(product_req)

# %%
product
# Out:
# <Response [200]>

# %%
product_data=bs(product.text)

# %%
product_data
# Out:
# <!DOCTYPE html>
# ...

# %%
comment_box=product_data.findAll("div",{"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Mind-blowing purchase</p></div><div class="row"><div class="t-ZTKy"><div><div class="">High quality camera😍</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_7da3ec457a024424a4139d6e08f134be.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_288e90668216465db51ab6a496caf12d.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_30095ede087a413fb80917c1c75bfd30.jpeg?q=90), 
# ...

# %%
del comment_box[10:]

# %%
count=0
for rating in comment_box:
    count+=1
    print(count)
    print(rating.div.div.div.div.text)
# Out:
# 1
# 5
# 2
# 4
# 3
# 5
# 4
# 5
# 5
# 4
# 6
# 5
# 7
# 5
# 8
# 4
# 9
# 5
# 10
# 5

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Mind-blowing purchase'

# %%
for comment in comment_box:
    print(comment.div.div.div.p.text)
# Out:
# Mind-blowing purchase
# Worth the money
# Awesome
# Just wow!
# Good choice
# Classy product
# Highly recommended
# Really Nice
# Brilliant
# Awesome

# %%
comment_box[0].div.div.div.div.div

# %%
comment_desc=product_data.find_all("div",{"class":"t-ZTKy"})

# %%
for desc in comment_desc:
    print(desc.div.div.text)
# Out:
# High quality camera😍
# Best mobile phoneCamera quality is very nice Battery backup is very good Sound quality is amazing.
# Switch from OnePlus to iPhone I am stunned with camera performance. Everything is perfect on  iPhone 15.
# Camera Quality Is Improved Loving It
# Very nice
# Nice ❤️
# I love this phone. The camera is amazing: its I am so happy
# Awesome camra quality superb camra 😊
# Totally happy!Camera 5Battery 5 Display 5Design 5
# Simply premium.

# %%
i=comment_box[0].findAll("div",{"class":"row _3n8db9"})

# %%
for name in comment_box:
    i=name.findAll("div",{"class":"row _3n8db9"})
    print(i[0].p.text)
# Out:
# Ajin V
# Sheetla Prasad Maurya
# Nikhil Kumar
# Prithivi Boruah
# Mousam  Guha Roy
# mohit  yadav
# Talim (sk)
# Ankit  Verma
# Rahul Shedge
# Saurabh Gothwad
